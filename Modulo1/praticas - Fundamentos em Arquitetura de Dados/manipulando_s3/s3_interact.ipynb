# %%
import boto3
import pandas as pd

# %%
#criar client s3 para manipular o bucket s3
s3_client = boto3.client('s3')

# %% [markdown]
# realizando download de arquivo em bucket utilizando API do aws s3

# %%
s3_client.download_file('caio-dev-edc','base_dacred_trat.csv','base_dacred_trat_down.csv')
customers_df = pd.read_csv('base_dacred_trat_down.csv')

customers_df
# Out:
#            Data  vendedor_codigo                              Nome  \
# 0     09.6.2021                2     DAVID MIRANDA DA SILVA JUNIOR
# 1     09.6.2021                2     NEIDE FATIMA FRANCISCO AMORIM
# 2     09.6.2021                2            ELIZAMA DA SILVA DIAS
# 3     10.6.2021                2       INGRID COSTA DE ALBUQUERQUE
# 4     10.6.2021                2          CRISTIANE SOUZA DA SILVA
# ..          ...              ...                               ...
# 946  27.10.2021                3       GRAZIELA DE OLIVEIRA SANTOS
# 947  27.10.2021                5  Eliziene bacelar de Lima Barbosa
# 948  27.10.2021               13       Andreson Cardoso dos Santos
# 949  27.10.2021                3       GLEICIANE DA GAMA GONCALVES
# 950  27.10.2021                3             William Castro Santos
#
#              CPF    Nª Telefone  numero_estado   Data Nasc  NUMERO_BANCO  \
# 0    32578625808    11985183580           24.0  24.10.1975           1.0
# ...

# %% [markdown]
# realizando upload de arquivo em bucket utilizando API do aws s3

# %%
s3.client.upload_file
