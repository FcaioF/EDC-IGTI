# %%
import os

# %%
raw_enade = 'D://caiof//Documents//GIT_Repos//EDC-IGTI//Modulo 3//base_dados//base_desafio2//microdados_enade_2017_LGPD//raw_data//'
files = os.listdir(raw_enade)

# %%
with open(f'{raw_enade}microdados2017_arq1.txt','r') as f:
    line =f.readline()

for _ in line:
    print(_) 






    # with open('myfile.txt') as f:
    # first_line = f.readline()
# Out:
# "
# N
# U
# _
# A
# N
# O
# "
# ;
# "
# C
# O
# _
# C
# U
# R
# S
# O
# "
# ;
# "
# C
# O
# _
# I
# E
# S
# "
# ;
# "
# C
# O
# _
# C
# A
# T
# E
# G
# A
# D
# "
# ;
# "
# C
# O
# _
# O
# R
# G
# A
# C
# A
# D
# "
# ;
# "
# C
# O
# _
# G
# R
# U
# P
# O
# "
# ;
# "
# C
# O
# _
# M
# O
# D
# A
# L
# I
# D
# A
# D
# E
# "
# ;
# "
# C
# O
# _
# M
# U
# N
# I
# C
# _
# C
# U
# R
# S
# O
# "
# ;
# "
# C
# O
# _
# U
# F
# _
# C
# U
# R
# S
# O
# "
# ;
# "
# C
# O
# _
# R
# E
# G
# I
# A
# O
# _
# C
# U
# R
# S
# O
# "
